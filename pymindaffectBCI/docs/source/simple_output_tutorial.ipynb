# %% [markdown]
# # Creating a Simple Output Module

# %% [markdown]
# An output module listens for selections from the MindAffect decoder and acts on them to create some output. By the end of this tutorial you will be able to:
#  * make a simple output module which prints "Hello World" when the presentation 'button' with ID=1 is selected.
#  * know how to make your own output modules to perform arbitary actions under brain control
#
# **Before starting this tutorial please read the** [how an evoked bci works](https://mindaffect-bci.readthedocs.io/en/latest/how_an_evoked_bci_works.html) **tutorial to gain a general understanding of the components of this BCI.  And the [quickstart tutorial](quickstart.ipynb) or [DIY Brain Computer Interface](DIY_brain_computer_interfacing.ipynb) for how they are used in the mindaffectBCI. **
#
# *The non-Jupyter Notebook version of this code and other output examples can be found in the* [examples/output](https://github.com/mindaffect/pymindaffectBCI/blob/doc/mindaffectBCI/examples/output/minimal_output.py) *directory*

# %% [markdown]
# First, we import the module responsible for translating selections to output, and create the utopia2output object:

# %%
# Import the utopia2output module
from mindaffectBCI.utopia2output import Utopia2Output

u2o=Utopia2Output()

# %% [markdown]
# ## Defining the Output function
# Now we define a function to print hello-world.

# %%
def helloworld(objID):
   print("hello world")

# %% [markdown]
# ## Connecting the Output function
# And connect it so it is run when the object with ID=1 is selected. You can create as many output functions as needed, and connect them to different object ID's by simply adding them to the dictionary as *key-value* pairs.

# %%
# set the objectID2Action dictionary to use our helloworld function if 1 is selected
u2o.objectID2Action={ 1:helloworld }

# %% [markdown]
# ## Start the BCI decoder in the background.
# To successfully test your presentation module it is important to have the other components of the BCI running. As explained in the [quickstart tutorial](quickstart.ipynb), additionally to the presentation we build here, we need the Hub, Decoder, and Acquisition components for a functioning BCI.
# For a quick test (with fake data) of this presentation module you can run all these components with a given configuration file using.
#
# N.B. if you run directly in this notebook, *don't forget to shutdown the decoder* at the end.

# %%
import mindaffectBCI.online_bci
config = mindaffectBCI.online_bci.load_config('fake_recogniser.json')
mindaffectBCI.online_bci.run(**config)
# Out:
# Loading config from: /home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/fake_recogniser.json
# Saving to /home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/decoder/../../logs
# Running command: ('java', '-jar', 'UtopiaServer.jar', '8400', '0', '/home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_fake_recogniser.txt')
# Server:cons
# Server:open server ports
# Server: Opening Port:8400
# Server: Opening UDP Port:8400
# Server: Utopia Server listening on: UDP:8400
# wlp107s0->/fe80:0:0:0:2624:8734:7d78:985b%wlp107s0 ll=true
# wlp107s0->/134.21.156.24 ll=false
# Server: Opening SSDP-ipv4 Port:
# wlp107s0->/fe80:0:0:0:2624:8734:7d78:985b%wlp107s0 ll=truesl=false
# wlp107s0->/134.21.156.24 ll=falsesl=false
# NIC=name:wlp107s0 (wlp107s0)
# SSDP NIC: name:wlp107s0 (wlp107s0)
# Server: Utopia Server listening on: SSDP:/0.0.0.0
# Server: Opening SSDP-v6 Port:
# wlp107s0->/fe80:0:0:0:2624:8734:7d78:985b%wlp107s0 ll=truesl=false
# wlp107s0->/134.21.156.24 ll=falsesl=false
# NIC=name:wlp107s0 (wlp107s0)
# Server: Utopia Server listening on: SSDP:/0.0.0.0
# write description.xml
# Server:writing file: ./description.xml
# Server: Ports open, waiting for connections
# setup logging file
# Server:logging new messages to file: /home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_fake_recogniser_230421_1015.txt
# Server: Utopia Server Status:
# Listening on Address :
#
# /134.21.156.24:8400
# /127.0.0.1:8400
#
#  Saving to :
# /home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_fake_recogniser_230421_1015.txt
# Already initialized!
# Server:  Waiting for connections/messages
# h+
# H+
# h+
# h+
# h+
# H+
# h+
# Starting fakedata
# h+
# Tring to connect to: localhost:8400
# Trying to connect to: localhost:8400
# Connected!
# Putting header. 4 ch @ 200 Hz
# 20 2 0.049991 400.072874 (samp,blk,s,hz)
#
# Server: New Client Connection : /127.0.0.1:54010
#
#
# Offset Update:0.0->-1.569447506E9
# ClientInfoSubscribed /127.0.0.1:54010 to : []
# HA
# Offset Update:-1.569447506E9->-1.569447508E9
# DDDDh+
#
# Offset Update:-1.569447508E9->-1.569447509E9
# DDDDGTK3Agg
# GTK3Cairo
# nbAgg
# Dh+
# H+
# DTkAgg
# TkCairo
# WebAgg
# agg
# cairo
# pdf
# Dpgf
# ps
# svg
# template
# Initial backend: template
# Using backend: TkAgg
# Starting: mindaffectBCI.decoder.decoder
# LOGDIR=/home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/decoder/../../logs/
# Trying to auto-discover the utopia-hub server
# making discovery object
# Using inteface: 134.21.156.24
# Got location: 134.21.156.24
# .
# SSDP::Query matched.  Sending response to/134.21.156.24:49053
# DDDDh+
# DDDDDHDh+
# DDDDDDh+
# DDDH+
# D.
# DDh+
# DDDDDDh+
# DDHDDDDh+
# DDDDDDh+
# H+
# D.
# DDDDh+
# DDDD620 62 3.050023 203.277166 (samp,blk,s,hz)DDHh+
#
# DDDDDDh+
# DDDH+
# .
# DDh+
# DDDDDDh+
# DDDDHDDh+
# DDDDDDh+
# DH+.
#
# D
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_86614/3364015070.py in <module>
#       1 import mindaffectBCI.online_bci
#       2 config = mindaffectBCI.online_bci.load_config('fake_recogniser.json')
# ----> 3 mindaffectBCI.online_bci.run(**config)
#
# ~/Desktop/pymindaffectBCI/mindaffectBCI/online_bci.py in run(label, logdir, block, acquisition, acq_args, decoder, decoder_args, presentation, presentation_args)
#     299     #--------------------------- PRESENTATION ------------------------------
#     300     # run the stimulus, in a background processwith our matrix and default parameters for a noise tag
# --> 301     presentation_process = startPresentationProcess(presentation, presentation_args)
#     302
#     303     if block == True:
#
# ~/Desktop/pymindaffectBCI/mindaffectBCI/online_bci.py in startPresentationProcess(presentation, presentation_args)
#     172 def startPresentationProcess(presentation,presentation_args):
#     173     target=None
# --> 174     if presentation.lower() == 'selectionMatrix'.lower() or presentation.lower() == 'mindaffectBCI.examples.presentation.selectionMatrix'.lower():
#     175         if presentation_args is None:
#     176             presentation_args = dict(symbols= [['Hello', 'Good bye'],
#
# AttributeError: 'bool' object has no attribute 'lower'
# DDDh+
# DDDDDDh+
# DDHDDDDh+
# DDD.
# Discovery returned 1 utopia-hub servers
# Discovered utopia-hub on 134.21.156.24 ...DH+
# Tring to connect to: 134.21.156.24:-1
# Trying to connect to: 134.21.156.24:8400
# Connected!
# geting some initial data to setup the ring buffer
#
#
# Server: New Client Connection : /134.21.156.24:44814
#
#
# Offset Update:0.0->-1.569447509E9
# ClientInfoSubscribed /134.21.156.24:44814 to : [DEMSN]
# HDDh+
# DDDDDDh+
# D1220 122 6.050506 201.636017 (samp,blk,s,hz)
# DDDHDDh+
# DDDDDDh+
# DH+
# HDDDDDh+
# DDDDDDh+
# DHDDDDh+
# DDDDDH+
# Hh+
# DDDDDDh+
# DDDDDDHh+
# DDDDDDh+
# DDEstimated sample rate 620 samp in 3.049 s =200.0
# resample: 200.0->100.0hz rsrate=2.0
# Estimated pre-processed sample rate=100.0
# resample: 200.0->100.0hz rsrate=2.0
# SigQ:
# raw_power=([0.4770536 1.1316767 1.172338  1.0392696]/10)
# pp_power=([0.04234073 0.09342304 0.55582663 0.20535149]/5)
# noise2sig=[10.26701513 11.11346483  1.10917927  4.06093027]
# SigQ:
# raw_power=([0.9389822 1.0612221 0.9296889 1.0189985]/10)
# pp_power=([0.38823932 0.5168672  0.47961269 0.42484648]/5)
# noise2sig=[1.41856543 1.0531813  0.93841591 1.39850994]
# SigQ:
# raw_power=([1.0159945 1.0391377 0.8985596 1.0279421]/10)
# pp_power=([0.42351933 0.54152046 0.45222723 0.50797967]/5)
# noise2sig=[1.39893313 0.91892604 0.98696478 1.02358897]
# clsfr=MultiCCA(evtlabs=['re', 'fe'], tau=45)
# .DSigQ:
# raw_power=([1.039461  0.9813745 1.0309253 1.0159643]/10)
# pp_power=([0.48898306 0.46274651 0.44168775 0.47566351]/5)
# noise2sig=[1.12576079 1.12076048 1.33405902 1.13588862]
# HDDD.DH+
# QHQDQDDh+
# QD.DD..DD1830 183 9.099736 201.104741 (samp,blk,s,hz).
# DDDDDh+
# D.D.D..D.D.HDDDDHDDh+
# .D..D.D..D.D.DDDDD.D.DSigQ:
# raw_power=([1.0371062  1.0020444  0.98751223 1.0098664 ]/10)
# pp_power=([0.55507685 0.45305252 0.43753861 0.4266433 ]/5)
# noise2sig=[0.86840101 1.21176222 1.25697161 1.3670039 ]
# .HD.D..D.Dh+
# QH+
# DHDDDD..D.D..D.D.DDh+
# DD.D.D..D.D..DHDDDDh+
# DHD.D..D.D..D.D.DDDDh+
# D.D.D..DSigQ:
# raw_power=([1.0541023 0.9632452 0.9868984 1.051466 ]/10)
# pp_power=([0.48245756 0.47753469 0.48481109 0.47711449]/5)
# noise2sig=[1.18486014 1.01712092 1.03563499 1.20380224]
# H.D.
# DDH+
# HDQDDh+
# .DD..DD..DDDDDDDh+.D.D.D..D.
# DDDDD..DH.D..D.D.DHDh+
# DDD.D.D..D.DSigQ:
# raw_power=([1.0510964 1.0112715 1.0131817 0.9828201]/10)
# pp_power=([0.49562165 0.4698732  0.49061925 0.45285547]/5)
# noise2sig=[1.12076378 1.15222209 1.0651079  1.17027321]
# .H.DDDDh+
# H+
# QDHD.D..D.D..D.D.DDDDh+
# 2430 243 12.100564 200.817090 (samp,blk,s,hz)
# .D.D..D.D.DDDDD.D.D..D.D.H..DDh+
# DDHDD.D..D.D..D.D.Dh+
# DDDDH+
# .DSigQ:
# raw_power=([1.0142537  0.97364897 0.9578601  0.97108126]/10)
# pp_power=([0.47416694 0.45833988 0.46380748 0.51404565]/5)
# noise2sig=[1.13902245 1.12429465 1.06521056 0.88909536]
# HD.
# .DD.DDHh+
# QDDDD.D.D.D.D.DDDh+
# DDD.D..D.D..DH.D.DDh+
# DHDD.D.D..D.D..DDDDh+
# DD.D..DSigQ:
# raw_power=([0.99804544 1.0540644  1.0084413  1.0015348 ]/10)
# pp_power=([0.47914765 0.50415129 0.4723737  0.44016398]/5)
# noise2sig=[1.0829601  1.09077    1.134838   1.27536751]
# H.D..D.D.DH+
# HQDDDh+
# D.D.D..D.D..D.D..D.D..D.DH..DD..DD..DD..DSigQ:
# raw_power=([1.0723261 1.0659213 0.987929  1.0598842]/10)
# pp_power=([0.56197619 0.42900991 0.472119   0.4836173 ]/5)
# noise2sig=[0.90813434 1.48460763 1.09254233 1.19157626]
# HD.D
# .D.D..D3040 304 15.150338 200.655593 (samp,blk,s,hz).
# D..D.D..D.D..D.D..D.D.H..D.D..D.D..D.D..DSigQ:
# raw_power=([1.0272624 0.9482233 1.0166643 1.0626018]/10)
# pp_power=([0.51245772 0.47676031 0.44028758 0.49752016]/5)
# noise2sig=[1.00457991 0.98888893 1.30909141 1.13579648]
# H.D..D.D..D.D..D.D..DD..DD..DD.D.HD.D.D.D.D.D..DSigQ:
# raw_power=([1.0343632 1.0295862 1.0364839 1.0023516]/10)
# pp_power=([0.50289807 0.51793293 0.47528659 0.51372842]/5)
# noise2sig=[1.05680476 0.98787551 1.18075556 0.95113137]
# H.D.
# .D.D..D.D..D.D..D.D..D.D..D.D..DH.D..D.D..D.D..D.HDSigQ:
# raw_power=([0.96979475 0.97936887 1.0586808  1.0728606 ]/10)
# pp_power=([0.43262024 0.42310749 0.50898492 0.41847457]/5)
# noise2sig=[1.2416768  1.31470462 1.07998454 1.56374146]
# ..D.D.3650 365 18.199974 200.549736 (samp,blk,s,hz).
# DD..DD.D.D.D.D.D.D.D.HD.D.D.D..D.D.DSigQ:
# raw_power=([1.061877   0.9970945  0.96693784 0.9880485 ]/10)
# pp_power=([0.44655334 0.45133471 0.45236326 0.4587308 ]/5)
# noise2sig=[1.37793992 1.20921303 1.13752514 1.15387432]
# H.D.
# .D.D..D.D..D.D..D.D..D.D..D.D..DH.D..D.D..D.D..DDSigQ:
# raw_power=([1.0829518  1.0767759  1.0207233  0.98895556]/10)
# pp_power=([0.47936823 0.43778425 0.43382742 0.43090826]/5)
# noise2sig=[1.25912299 1.45960403 1.35283273 1.29504897]
# H..DD..DD.D.D.D..D.D..D.D..D.D.H..D.D..D.D..D.D..DH.DSigQ:
# raw_power=([1.057794   1.0360861  1.0790594  0.98391724]/10)
# pp_power=([0.49370451 0.45371989 0.474583   0.40844732]/5)
# noise2sig=[1.14256494 1.28353685 1.27369998 1.40892077]
# .
# .D4250 425 21.200166 200.470124 (samp,blk,s,hz).D
# ..D.D..D.D..D.D..D.D..DD..DHD.D.D.D.D.D..DH.DSigQ:
# raw_power=([0.8882354 1.0560347 1.0535387 1.0578647]/10)
# pp_power=([0.38455335 0.50765832 0.49076152 0.44192636]/5)
# noise2sig=[1.30978454 1.08020759 1.14674263 1.39375776]
# .D.D..D.D..D.D..D.D..D.D..D.D.H..D.D..D.D..D.D..DH.D.
# .DSigQ:
# raw_power=([0.9982189 1.0015104 1.1000565 1.0155208]/10)
# pp_power=([0.46881331 0.54290576 0.50651283 0.44691401]/5)
# noise2sig=[1.12924608 0.84472235 1.17182361 1.27229576]
# D.D.D.D.D.D..D.D..D.D..D.D.H..D.D..D.D..D.D..DH.D.4860 486 24.249494 200.416550 (samp,blk,s,hz)
# .DSigQ:
# raw_power=([1.0037285 1.0418817 0.9898817 0.9658634]/10)
# pp_power=([0.49620225 0.55910759 0.51349775 0.41277412]/5)
# noise2sig=[1.02282138 0.86347262 0.92772353 1.33993209]
# .D..D.D..D.D..D.D..DD..DD..DHD.D.D.D.D.D.HD.DSigQ:
# raw_power=([1.0255414 1.0332129 1.0663912 1.0213317]/10)
# pp_power=([0.51423951 0.49228928 0.56241168 0.43436176]/5)
# noise2sig=[0.99428751 1.0987922  0.89610435 1.35133881]
# .
# .D.D..D.D..D.D..D.D..D.D..D.DH..D.D..D.D..DD..DHD..DSigQ:
# raw_power=([1.0148511  0.99091816 1.076832   1.0129681 ]/10)
# pp_power=([0.47680667 0.45235664 0.51750735 0.51032886]/5)
# noise2sig=[1.12843307 1.19056838 1.08080532 0.98493196]
# D.D.D.D..D.D..D.D..D.D..D.D.H..D.D..D.D..D.D.5460 546 27.250352 200.364381 (samp,blk,s,hz)
# .DH.DSigQ:
# raw_power=([1.0198412  1.0337719  0.98794454 0.98457015]/10)
# pp_power=([0.43844409 0.48472744 0.46336975 0.46720364]/5)
# noise2sig=[1.32604618 1.13268691 1.13208685 1.10736829]
# .
# .D.D..D.D..D.D..D.D..D.D..DD..DHD..DD.D.D.D.DH.DSigQ:
# raw_power=([1.0344104 1.0139347 0.9492178 1.058926 ]/10)
# pp_power=([0.51207079 0.43358406 0.44796078 0.44265401]/5)
# noise2sig=[1.02005342 1.33849635 1.11897525 1.39222049]
# .D.D..D.D..D.D..D.D..D.D..D.D..DH.D..D.D..D.D..DH.D.
# .DSigQ:
# raw_power=([1.0478326  0.94763887 0.9478661  1.0625424 ]/10)
# pp_power=([0.52292959 0.41075333 0.42079597 0.51449457]/5)
# noise2sig=[1.0037738  1.30707534 1.25255506 1.06521605]
# .D..D.D..D.D..DD..DD.D.D.D.HD.D.D.D..D6070 607 30.300621 200.325926 (samp,blk,s,hz).
# D.H.D.D..DSigQ:
# raw_power=([1.1040347 1.0027484 0.9223904 0.9561383]/10)
# pp_power=([0.50002887 0.44874956 0.4093731  0.44291439]/5)
# noise2sig=[1.20794182 1.23453894 1.25317784 1.15874293]
# .D..D.D..D.D..D.D..D.D..D.D..DH.D..D.D..D.D..DH.D.
# .D.DSigQ:
# raw_power=([1.0102863 0.987097  1.0036198 0.9483965]/10)
# pp_power=([0.48073385 0.4432886  0.48631171 0.42930476]/5)
# noise2sig=[1.10155022 1.22675932 1.06373766 1.20914507]
# ..D.D..D.D..D.D..D.D..DD..DDH..DD.D.D.D..DH.D..D.DSigQ:
# raw_power=([0.91703486 0.9474936  0.98296267 0.99446887]/10)
# pp_power=([0.38905965 0.40118209 0.43879134 0.45191244]/5)
# noise2sig=[1.35705466 1.36175454 1.2401597  1.20057865]
# ..D.D..D.D..D.D..D.D..D.D..D.D.H..D.D..D6680 668 33.349719 200.301539 (samp,blk,s,hz).
# D..D.H.D.
# .D.D..DSigQ:
# raw_power=([0.99623126 1.0087442  1.0141199  1.0553911 ]/10)
# pp_power=([0.47125161 0.46512504 0.4668198  0.46374311]/5)
# noise2sig=[1.11401135 1.16875928 1.17240112 1.2758097 ]
# .D..D.D..D.D..D.D..DD..DD.D.H.D.D..D.D..DH.D..D.DSigQ:
# raw_power=([0.95315856 1.1332431  1.0219384  0.99786574]/10)
# pp_power=([0.40992278 0.50124415 0.5040566  0.48744563]/5)
# noise2sig=[1.32521489 1.26086048 1.02742797 1.04713238]
# .D.D..D.D..D.D..D.D..D.D..D.D..DH.D..D.D..D.HD.
# .D.D..DSigQ:
# raw_power=([1.0086576 1.0088906 1.0072101 1.0405158]/10)
# pp_power=([0.40460354 0.48421202 0.46404085 0.46840161]/5)
# noise2sig=[1.49295293 1.08357203 1.17052042 1.22141804]
# D..DD..DD.D.D.D.D.D.D.D.HD.D.7290 729 36.399387 200.278096 (samp,blk,s,hz)
# .D.D..DH.D..D.DSigQ:
# raw_power=([0.947472  1.0253242 1.0521271 1.057584 ]/10)
# pp_power=([0.39940348 0.49341566 0.44748226 0.48513939]/5)
# noise2sig=[1.3722176  1.07801313 1.35121527 1.17995912]
# .D.D..D.D..D.D..D.D..D.D..D.D..DH.D..D.D..DH.D.
# .D.D..DSigQ:
# raw_power=([0.989552   1.0242919  1.0058796  0.97913957]/10)
# pp_power=([0.45201342 0.41093346 0.4751467  0.50128431]/5)
# noise2sig=[1.18920939 1.4925979  1.11698753 0.95326196]
# D..DD..DD.D..D.D.D.D.D.D.DH.D..D.D..DH.D.D.D.DSigQ:
# raw_power=([1.0109252  0.97662836 1.0310494  0.9537635 ]/10)
# pp_power=([0.45783762 0.44379822 0.49990388 0.47148887]/5)
# noise2sig=[1.20804303 1.20061351 1.06249524 1.02287594]
# .D..D.D..D.D..D.D..D.D..D.D..D7890 789 39.400152 200.253035 (samp,blk,s,hz).
# D.H..D.D..D.HD.
# .D.D..D.DSigQ:
# raw_power=([0.9535741 0.9948932 1.0270348 1.0471978]/10)
# pp_power=([0.40489403 0.42661764 0.46993403 0.45565089]/5)
# noise2sig=[1.35512021 1.33204887 1.18548712 1.29824594]
# ..DD..DD.D.D.D..D.D..D.D..D.D.H..D.D..DH.D..D.D..D.DSigQ:
# raw_power=([0.99702287 1.0661037  1.0315032  1.0192887 ]/10)
# pp_power=([0.47196408 0.4815691  0.49380631 0.44349151]/5)
# noise2sig=[1.11249735 1.21381251 1.08888219 1.29832732]
# ..D.D..D.D..D.D..D.D..DD..DD..DHD.D.DH.D.
# .D.D..D.DSigQ:
# raw_power=([1.0409932 1.0248747 1.0336514 1.0091044]/10)
# pp_power=([0.49684262 0.46002564 0.49508903 0.47054045]/5)
# noise2sig=[1.09521723 1.22786426 1.08780903 1.14456454]
# ..D.D..D.D..D.D..D.D..D.D.8500 850 42.450300 200.234157 (samp,blk,s,hz)
# .D.D..DH.D..DHD..DD..DDSigQ:
# raw_power=([1.0105202 1.0084331 0.9711698 1.0477275]/10)
# pp_power=([0.47104948 0.45485946 0.43643295 0.47667246]/5)
# noise2sig=[1.1452528  1.21702126 1.22524405 1.19800293]
# ..DD.D.D.D.D.D..D.D.D.D..D.D.H.D.D..DH.D.
# .D.D..D.DSigQ:
# raw_power=([0.96086955 0.97698706 1.0154841  1.0246018 ]/10)
# pp_power=([0.45208847 0.46286733 0.46062454 0.4867281 ]/5)
# noise2sig=[1.12540157 1.11072807 1.20458095 1.10508045]
# ..D.D..DHH.D.H..DH.D.H..DHD.H..DHD.H..DHD.H.D.HHD.D..DH.D..D.D..D.DSigQ:
# raw_power=([1.0102845  0.9424041  0.9954078  0.96453345]/10)
# pp_power=([0.48293036 0.40017844 0.42919919 0.48611639]/5)
# noise2sig=[1.09198805 1.35495967 1.3192211  0.98416154]
# .
# Process Process-1:
# Process Process-2:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/decoder/decoder.py", line 825, in run
#     newmsgs, nsamp, nstim = ui.update()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/decoder/UtopiaDataInterface.py", line 502, in update
#     sleep(mintime_ms/1000.0)
#   File "/home/christophe/Desktop/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_fakedata.py", line 71, in run
#     sleep(max(0, (t0 + nSamp*sample_interval - client.getTimeStamp()) / 1000))
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# Alternatively you can run this config from the command line with:
#
# ```python3 -m mindaffectBCI.online_bci --config_file fake_recogniser.json```
#
# Or from you Anaconda environment:
#
# ```python -m mindaffectBCI.online_bci --config_file fake_recognizer.json```
#
# **See our tutorial** [Running Custom Presentation](simple_integration_tutorial.ipynb) **to set-up a BCI using your own Presentation module**

# %% [markdown]
# ## Connect and Run
# We now connect our output module to a running decoder and run the main loop. Selection of ID=1 will result in printing "Hello World" to this prompt.

# %%
# connect
u2o.connect()

# run the main loop
u2o.run()
# Out:
# DConnecting to utopia on None : None , 30000
# Trying to auto-discover the utopia-hub server
# making discovery object
# Using inteface: 134.21.156.24
# SSDP::Query matched.  Sending response to/134.21.156.24:41017
# Got location: 134.21.156.24
# .
# DDDDh+
# DDDDHDDh+
# DDDDDH+
# Dh+
# HQDDDD.
# DDh+
# DDDDDDh+
# DHDDDDh+
# DDDH+
# HDQDDh+
# D.
# DDDDh+
# DDDDDDHh+
# DDDDDDh+
# DH+
# HQDDD.
# DDh+
# DDDDDDh+
# DDDHDDDh+
# DDDHH+
# DQDDh+
# .
# DDDDDDh+
# DDDDDHh+
# DDDDDDh+
# DH+
# HQDD.
# SSDP::Query matched.  Sending response to/134.21.156.24:41017
# Got location: 134.21.156.24
# .
# DDDh+
# DDDDDDh+
# DDDHDDDh+
# DDDDH+
# HQD.
# Dh+
# DDDDDDh+
# DDDDDHh+
# DDDDDDh+
# DH+
# HDQ.
# DDDDh+
# DDDDDDh+
# DDDHDDDh+
# DDDDH+
# H.Dh+
#
# QDDDDDDh+
# DDDDDh+
# DHDDDDDh+
# DDH+
# DH.
# DDQh+
# DDDDDDh+
# DDDDDHh+
# DDDDDDh+
# DH+
# .
# SSDP::Query matched.  Sending response to/134.21.156.24:41017
# Got location: 134.21.156.24
# .
# HDDDQDDh+
# DDDDDDh+
# DDDHDDDh+
# DDDH+
# .
# DHDQh+
# DDDDDDh+
# DDDDDDHh+
# DDDDDDh+
# .
# DH+
# DHDDQDh+
# DDDDDh+
# DDDDDHDh+
# DDDD.
# Dh+
# DH+
# HDQDDDDh+
# DDDDDDh+
# DDDHDDDh+
# D.
# DDDH+
# HDQh+
# DDDDDDh+
# DDDDDDh+
# DHDDD.
# SSDP::Query matched.  Sending response to/134.21.156.24:41017
# Got location: 134.21.156.24
# .
# DDh+
# DH+
# HDDDQDDh+
# DDDDDDh+
# DDDHDDDh+
# .
# DDDH+
# DHDDh+
# QDDDDDh+
# DDDDDDh+
# DHDD.
# DDDh+
# DH+
# HDDDQDDh+
# DDDDDDh+
# DDDDHD.
# Dh+
# DDDDH+
# HDDh+
# DQDDDDh+
# DDDDDDh+
# DDH.
# DDDDh+
# DHH+
# DDDDh+
# DQDDDDDh+
# DDDDD.
# SSDP::Query matched.  Sending response to/134.21.156.24:41017
# h+Got location: 134.21.156.24
#
# .
# DHDDDDDh+
# H+
# HDDDQDDDh+
# DDDDDDh+
# DD.
# DDHDDh+
# DDHH+
# DDDDh+
# DQDDDDDh+
# DDDD.
# Dh+
# DHDDDDDh+
# H+
# HDDDQDDh+
# DDDDDDh+
# DD.
# DDDHh+
# DDDDH+
# HDDh+
# DDDQDDh+
# DDDDDDh+
# .
# DDDDHDDh+
# DDH+
# HDDDDh+
# QDDDDDDh+
# DD.
# SSDP::Query matched.  Sending response to/134.21.156.24:41017
# Got location: 134.21.156.24
# .
# DDDh+
# DDHDDDHh+
# H+
# DDDDDQDh+
# DDDDDDh+
# .
# DDDDDDHh+
# DDDH+
# HDDDh+
# DDQDDDDh+
# DD.D
# DDDh+
# DDDHDDDh+
# H+
# HDDDDDQh+
# DDDDDDh+
# .
# DDDDDDh+
# DHDDH+
# DHDDh+
# DDQDDDh+
# DDD.
# DDDh+
# DDDDHDDh+
# DH+
# HDDDDDh+
# QDDD.
# Discovery returned 6 utopia-hub servers
# Discovered utopia-hub on 134.21.156.24 ...
# Tring to connect to: 134.21.156.24:8400
# Trying to connect to: 134.21.156.24:8400
# Connected!
#
# Server: New Client Connection : /134.21.156.24:37506
#
#
# Offset Update:0.0->-1.569447507E9
#
# Offset Update:-1.569447507E9->-1.569447508E9
# HHD
# Offset Update:-1.569447508E9->-1.569447509E9
# HDHh+
# DHDHDHDHDHh+
# DHDHDHIn SelectionModeHClientInfoSubscribed /134.21.156.24:37506 to : [S]
#
# Waiting for messages
# .DDDh+
# .H+
# H.DDDDDQh+
# D
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_86614/2428361621.py in <module>
#       3
#       4 # run the main loop
# ----> 5 u2o.run()
#
# ~/Desktop/pymindaffectBCI/mindaffectBCI/utopia2output.py in run(self, timeout_ms)
#     119         self.outputActivated=False
#     120         while True:
# --> 121             newmsgs = self.client.getNewMessages(timeout_ms)
#     122             if not self.outputPressThreshold is None:
#     123                 # Perr output mode
#
# ~/Desktop/pymindaffectBCI/mindaffectBCI/utopiaclient.py in getNewMessages(self, timeout_ms)
#    1296         """
#    1297         # get all the data in the socket
# -> 1298         buf = self.recvall(timeout_ms)
#    1299         # append to the receive buffer
#    1300         self.recvbuf = self.recvbuf + buf
#
# ~/Desktop/pymindaffectBCI/mindaffectBCI/utopiaclient.py in recvall(self, timeout_ms)
#    1278         data=[]
#    1279         try:
# -> 1280             data = self.sock.recv(self.MAXMESSAGESIZE)
#    1281         except socket.timeout:
#    1282             pass
#
# KeyboardInterrupt:
