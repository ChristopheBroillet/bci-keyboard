# %%
import mindaffectBCI.online_bci

# %%
# load the config-file to use.  Here we use the default noisetag config file:
config = mindaffectBCI.online_bci.load_config("noisetag_bci")
# Out:
# Loading config from: /Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/noisetag_bci.json

# %%
# N.B. uncomment the following to run with fakedata driver, if you don't have an amp connected
config['acquisition']='fakedata'

mindaffectBCI.online_bci.run(**config)
# Out:
# Saving to /Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs
# Running command: ('java', '-jar', 'UtopiaServer.jar', '8400', '0', '/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_noisetag_bci.txt')
# Server:cons
# Server:open server ports
# Server: Opening Port:8400
# Server: Opening UDP Port:8400
# Server: Utopia Server listening on: UDP:8400
# llw0->/fe80:0:0:0:34a2:d8ff:fe5a:d14%llw0 ll=true
# awdl0->/fe80:0:0:0:34a2:d8ff:fe5a:d14%awdl0 ll=true
# anpi0->/fe80:0:0:0:e0f2:6eff:feed:a080%anpi0 ll=true
# anpi1->/fe80:0:0:0:e0f2:6eff:feed:a081%anpi1 ll=true
# en0->/192.168.1.101 ll=false
# Server: Opening SSDP-ipv4 Port:
# llw0->/fe80:0:0:0:34a2:d8ff:fe5a:d14%llw0 ll=truesl=false
# awdl0->/fe80:0:0:0:34a2:d8ff:fe5a:d14%awdl0 ll=truesl=false
# anpi0->/fe80:0:0:0:e0f2:6eff:feed:a080%anpi0 ll=truesl=false
# anpi1->/fe80:0:0:0:e0f2:6eff:feed:a081%anpi1 ll=truesl=false
# en0->/192.168.1.101 ll=falsesl=true
# NIC=name:en0 (en0)
# SSDP NIC: name:en0 (en0)
# Server: Utopia Server listening on: SSDP:/0.0.0.0
# Server: Opening SSDP-v6 Port:
# llw0->/fe80:0:0:0:34a2:d8ff:fe5a:d14%llw0 ll=truesl=false
# awdl0->/fe80:0:0:0:34a2:d8ff:fe5a:d14%awdl0 ll=truesl=false
# anpi0->/fe80:0:0:0:e0f2:6eff:feed:a080%anpi0 ll=truesl=false
# anpi1->/fe80:0:0:0:e0f2:6eff:feed:a081%anpi1 ll=truesl=false
# en0->/192.168.1.101 ll=falsesl=true
# NIC=name:en0 (en0)
# Server: Couldn't setup SSDP server socket
# Address family not supported by protocol family
# write description.xml
# Server:writing file: ./description.xml
# Server: Ports open, waiting for connections
# setup logging file
# Server:logging new messages to file: /Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_noisetag_bci_230421_1814.txt
# Server: Utopia Server Status:
# Listening on Address :
#
# /192.168.1.101:8400
# /127.0.0.1:8400
#
#  Saving to :
# /Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_noisetag_bci_230421_1814.txt
# Already initialized!
# Server:  Waiting for connections/messages
# h+
# H+
# h+
# h+
# h+
# Starting fakedata
# Starting: mindaffectBCI.decoder.decoder
# H+
# h+
# Tring to connect to: localhost:8400
# Trying to connect to: localhost:8400
# Connected!
#
# Server: New Client Connection : /127.0.0.1:52567
#
#
# Offset Update:0.0->-1.566873492E9
# ClientInfoSubscribed /127.0.0.1:52567 to : []
# HADPutting header. 4 ch @ 200 Hz
# 20 2 0.062602 319.478391 (samp,blk,s,hz)
#
# Offset Update:-1.566873492E9->-1.566873496E9
# Dh+
#
# Offset Update:-1.566873496E9->-1.566873497E9
# DDDDDDh+
# DDDDDH+
# Dh+
# DDDD
# Offset Update:-1.566873497E9->-1.566873498E9
# Dh+
# DDHDDDDh+
# DDDSSDP::Query matched.  Sending response to/192.168.1.101:51368
# DDh+
# DDDH+
# DDDh+
# DDDDDDHh+
# DDDDDh+
# DDDDDDh+
# DH+
# DDDDh+
# DDDD630 63 3.099695 203.245805 (samp,blk,s,hz)
# DHh+
# DDDDDDh+
# DDDDDh+
# H+
# DDDDDDh+
# DDDDHDDh+
# DDDDDh+
# DDDDH+
# 2023-04-21 18:14:38.717 Python[54683:606912] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/8w/l2m8r9210g3_2wybgky04r_w0000gn/T/org.python.python.savedState
# DDh+
# DDDDDDh+
# SSDP::Query matched.  Sending response to/192.168.1.101:50529
# Dpydir=/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI
# Electrode Quality (3600000ms)
# stage transition
# connecting screen
# Not connected yet!!
# Trying to auto-discover the utopia-hub server
# making discovery object
# Using inteface: 192.168.1.101
# Got location: 192.168.1.101
# .
# .
# Discovery returned 1 utopia-hub servers
# Discovered utopia-hub on 192.168.1.101 ...
# Tring to connect to: 192.168.1.101:-1
# Trying to connect to: 192.168.1.101:8400
# Connected!
#
# Server: New Client Connection : /192.168.1.101:52587
#
#
# Offset Update:0.0->-1.566873497E9
# ClientInfoSubscribed /192.168.1.101:52587 to : [PSNMEQ]
# HClientInfoSubscribed /192.168.1.101:52587 to : [MSPQ]
# DHDDDh+
# DDDDDDh+
# DDH+
# DDDh+
# DDDD1240 124 6.149000 201.658809 (samp,blk,s,hz)
# DDh+
#
# Offset Update:-1.566873497E9->-1.566873498E9
# MHDHDD
# Server: New Client Connection : /192.168.1.101:52590
#
# MacOSX
# nbAgg
# TkAgg
# WebAgg
# WX
# WXAgg
# agg
# pdf
# pgf
# ps
# svg
# template
# Initial backend: template
# Using backend: TkAgg
# LOGDIR=/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs/
# Trying to auto-discover the utopia-hub server
# making discovery object
# Using inteface: 192.168.1.101
# Got location: 192.168.1.101
# .
# .
# .
# .
# .
# .
# Discovery returned 1 utopia-hub servers
# Discovered utopia-hub on 192.168.1.101 ...
# Tring to connect to: 192.168.1.101:-1
# Trying to connect to: 192.168.1.101:8400
# Connected!
# D
# Offset Update:0.0->-1.566873497E9
# ClientInfoSubscribed /192.168.1.101:52590 to : [DEMSN]
# HDh+
# DDDDDDh+
# DH+
# DDDDDh+
# DDDDDHDh+
# DDHDDDDh+
# DDDDH+
# DDh+
# DDDDDDh+
# DDHDDD
# Offset Update:-1.566873497E9->-1.566873498E9
# Hh+
# DDDDDDh+
# DDH+
# DDDMHDh+
# D1850 185 9.198903 201.110940 (samp,blk,s,hz)
# DDDDh+
# DHDQQQDgeting some initial data to setup the ring buffer
# Estimated sample rate 610 samp in 3.0 s =200.0
# resample: 200.0->100.0hz rsrate=2.0
# Estimated pre-processed sample rate=100.0
# resample: 200.0->100.0hz rsrate=2.0
# SigQ:
# raw_power=([0.8120748 1.1323134 0.9729067 0.7456461]/10)
# pp_power=([0.06132089 0.0552769  0.04835383 0.04626328]/5)
# noise2sig=[12.24303671 19.48438734 19.1205699  15.11745168]
# SigQ:
# raw_power=([1.0760543  0.99419934 1.093156   1.0147884 ]/10)
# pp_power=([0.51350747 0.51087889 0.36196698 0.40921638]/5)
# noise2sig=[1.0954989  0.94605678 2.02004336 1.47983329]
# SigQ:
# raw_power=([0.98603684 0.9876956  1.0172385  1.0005023 ]/10)
# pp_power=([0.46486851 0.44543254 0.46151073 0.37467961]/5)
# noise2sig=[1.12110912 1.21738531 1.20414917 1.67028766]
# clsfr=MultiCCA(evtlabs=['re', 'fe'], tau=45)
# .DHD.DQDDh+
# SigQ:
# raw_power=([0.9587015 1.0086906 1.0422416 1.0528454]/10)
# pp_power=([0.36246901 0.43184828 0.46664662 0.41141665]/5)
# noise2sig=[1.64491986 1.33575228 1.23347075 1.55907328]
# ..DDDD..DDD..DD.DDDh+
# H+
# ..DDHDD..DDDD..DDDDh+
# ..DDDD..DDDDH..DDHDDh+
# ..DHDD.DQDSigQ:
# raw_power=([0.9508737 0.960488  1.1000265 1.0371383]/10)
# pp_power=([0.36570679 0.48843687 0.44554096 0.45458103]/5)
# noise2sig=[1.6000985  0.96645274 1.46896824 1.28152581]
# .DD.DD.DD.DDh+
# .DD.DDH+
# ..DHD.DD..DD.DDh+
# ..DD.DD..DD.DD..DDh+
# .DDH..DHD.D.
# D.DHD.DD..DQh+
# DSigQ:
# raw_power=([0.9906347 1.0500243 1.048703  1.0804968]/10)
# pp_power=([0.38981145 0.46227203 0.48203482 0.44232198]/5)
# noise2sig=[1.54131753 1.27144236 1.17557511 1.44278338]
# .DD..DD.DD..DD.DDh+
# ..DDH+
# .D.HD..DD.DD..DD.D2460 246 12.248596 200.839342 (samp,blk,s,hz)
# Dh+
# ..DD.DD..DD.DD..DDH.D.HDh+
# ..DHD.DD..DQDSigQ:
# raw_power=([0.97427136 0.98647916 0.9176717  1.0080198 ]/10)
# pp_power=([0.43376565 0.40387665 0.39751652 0.46337214]/5)
# noise2sig=[1.24607769 1.44252587 1.30851208 1.1754001 ]
# .DD..DD.DDh+
# ..DD.DD..DD.DDH+
# ..DHD.DDh+
# ..DD.DD..DD.DD..DD.DDh+
# ..DD.D.
# DH.DHHD.DD..DDh+
# .DQDSigQ:
# raw_power=([1.0210141  0.9847035  0.98160803 0.990373  ]/10)
# pp_power=([0.48259684 0.45981606 0.40865239 0.46352393]/5)
# noise2sig=[1.11566675 1.14151608 1.40206114 1.1366168 ]
# ..DD.DD..DD.DD..DDh+
# .DD..DDH+
# .D.HD..DD.DD..DDh+
# .DD..DD.DMH.M.HD.
# New Mode: idle
# .DD.DDHh+
# ..DHHD.DD..DD.DD..DQDSigQ:
# raw_power=([0.9924479 0.9904608 1.0594671 1.0193933]/10)
# pp_power=([0.41601335 0.42561265 0.40732941 0.45443139]/5)
# noise2sig=[1.38561557 1.32714141 1.60100808 1.24322821]
# .DDh+
# ..DD.DD..DD.DD..DD.DDh+
# H+
# D..DHDD3070 307 15.298035 200.679366 (samp,blk,s,hz)
# D..DDDD..DDDh+
# D..DD.
# DDH.DHDHDD..DDDh+
# D..DDQDDSigQ:
# raw_power=([1.0584633  1.0412999  1.0115465  0.95681894]/10)
# pp_power=([0.37649706 0.32495642 0.41188334 0.43159078]/5)
# noise2sig=[1.81134553 2.20442952 1.45590534 1.21695868]
# ..DDDD..DDDh+
# D..DDDDH+
# ..DDHD.DD.DDh+
# .DD..DD.DD.DD.DDHh+
# .DHHD.DD.DD.DD.DD.DQDh+
# SigQ:
# raw_power=([0.9554233  0.98286456 0.9622799  1.030121  ]/10)
# pp_power=([0.43825019 0.41755081 0.42649445 0.50284437]/5)
# noise2sig=[1.18008643 1.35388012 1.25625423 1.04858805]
# .DD.DD..DD.DD.DD.DDh+
# .DD.DH+
# .HD..DD.DD.DD.DDh+
# .DD.D.
# D.DHDH.D.HD..DD.DDh+
# ..DD.DD..DQDSigQ:
# raw_power=([1.0025747  0.92970735 1.0449147  0.9703561 ]/10)
# pp_power=([0.42113605 0.4276099  0.45090669 0.39266225]/5)
# noise2sig=[1.38064324 1.1741951  1.31736355 1.47122331]
# .DD..DD.DDh+
# ..DD.DD..DDH+
# .D.H3670 367 18.298729 200.560376 (samp,blk,s,hz)
# D..DD.DDh+
# ..DD.DD..DD.DD..DHDH.D.HDh+
# ..DD.DD..DD.DD..DQDSigQ:
# raw_power=([1.0634819  1.0250798  1.03184    0.98592216]/10)
# pp_power=([0.43012681 0.45630257 0.43625915 0.42381159]/5)
# noise2sig=[1.47248464 1.24649153 1.36519961 1.32632184]
# .DDh+
# ..DD.DD..DD.DD..DD.DDh+
# H+
# ..DHD.DD..DD.DD..DD.D.
# Dh+
# .DHD.DDH..DHD.DD..DD.DDh+
# ..DD.DQDSigQ:
# raw_power=([0.9470263  1.0082737  0.96573037 0.95939696]/10)
# pp_power=([0.37117558 0.46237924 0.43740952 0.42402392]/5)
# noise2sig=[1.55142411 1.18062065 1.20784033 1.26260102]
# ..DD.DD..DD.DDh+
# ..DD.DD..DDH+
# .D.HD..DD.DDh+
# ..DD.DD..DHD.DD..DDHh+
# .D.HD..DD.DD..DD.DD..DQh+
# DSigQ:
# raw_power=([0.92249596 1.007665   0.9435816  0.99129194]/10)
# pp_power=([0.43593125 0.43473598 0.38832047 0.4454805 ]/5)
# noise2sig=[1.11615012 1.31787819 1.42990427 1.22521959]
# .DD..DD.DD..DD.DDh+
# ..D4280 428 21.347804 200.489005 (samp,blk,s,hz)
# D.DDH+
# ..DDH.DDD..D.D.
# Dh+
# .DDH.DDD..DDDHD..DHDDh+
# D..DDDD..DDQDDSigQ:
# raw_power=([0.9768129  1.0362645  1.0451205  0.97847104]/10)
# pp_power=([0.43399991 0.43823743 0.47387403 0.43662828]/5)
# noise2sig=[1.25072141 1.36461898 1.20548163 1.24097035]
# ..DDDh+
# D..DDDD..DDDDh+
# H+
# ..DDHD.DD.DD.DD.DHD.DDh+
# ..DD.DDH..DHD.DD..DDh+
# .DD.DD.DQDSigQ:
# raw_power=([1.002526   0.9644332  0.99946177 0.95163065]/10)
# pp_power=([0.46323756 0.38403829 0.4910063  0.41462711]/5)
# noise2sig=[1.1641726  1.51129436 1.03553755 1.29514818]
# ..DD.DD..DDh+
# .DD..DD.DD..DDH+
# .D.HD..DDh+
# .D.
# D.DHD.DD..DD.DDh+
# ..DDH.D.HD..DD.DD..DDh+
# .DQDSigQ:
# raw_power=([1.0158533  0.99478954 1.0908233  1.0045396 ]/10)
# pp_power=([0.49591845 0.42802755 0.46798045 0.47270186]/5)
# noise2sig=[1.04842812 1.32412503 1.33091638 1.12510187]
# ..DD.DD..DD.D4880 488 24.348838 200.420241 (samp,blk,s,hz)
# D..DDh+
# .DD..DD.DDH+
# ..DHD.DD..DHh+
# D.DD..DD.DD..DD.DDHh+
# ..DHD.DD..DD.DD..DQDSigQ:
# raw_power=([1.0064868  0.98406625 0.9859498  0.9664466 ]/10)
# pp_power=([0.4580545  0.38915361 0.38363807 0.44929945]/5)
# noise2sig=[1.19730791 1.52873472 1.56999993 1.15100769]
# .DDh+
# ..DD.DD..DD.DD..DD.DDh+
# ..DDH+
# .D.H.
# D.DHD.DD..DD.DDh+
# ..DD.DD..D
# Offset Update:-1.566873498E9->-1.566873499E9
# DH.D.HD..DD.DDh+
# ..DD.DQDSigQ:
# raw_power=([1.0806067  1.0069188  0.9712337  0.93934184]/10)
# pp_power=([0.47206456 0.44950239 0.41983369 0.39706606]/5)
# noise2sig=[1.28910788 1.24007437 1.31337731 1.3657067 ]
# ..DD.DD..DD.DDh+
# ..DD.DD..DDH+
# .D.HD..DHD.DDh+
# D..DDD..DD.DDD..DDDHh+
# D..DHDD..DD.DDD..DQh+
# SigQ:
# raw_power=([1.0568632  1.0166683  0.97794443 1.0000415 ]/10)
# pp_power=([0.43593853 0.45221496 0.43904465 0.41484669]/5)
# noise2sig=[1.42433994 1.248197   1.22743728 1.41062909]
# DD5490 549 27.398717 200.374347 (samp,blk,s,hz)
# D..DDDD..DDDDh+
# ..DD.
# DH+
# D.D
# Offset Update:-1.566873498E9->-1.566873499E9
# HHDD.DD.DD.DDh+
# .DD.DD.DD.DDH.DHD.DDh+
# .DD.DD.DQDSigQ:
# raw_power=([1.0348183 0.9985547 0.9338885 0.9677491]/10)
# pp_power=([0.43188479 0.42201111 0.46695492 0.4452956 ]/5)
# noise2sig=[1.39605172 1.3661811  0.9999543  1.17327348]
# .DD..DNewSubscriptions: PSNMEQ
# NewSubscriptions: MSPQ
# stage transition
# main menu
# stage transition
# reset
# stage transition
# main menu
# stage transition
# settings
# s:115
# s:115
# f:102
# d:100
# a:97
# q:113
# q:113
# D.DServer:Read error:Connection reset
# h+
# D..D
