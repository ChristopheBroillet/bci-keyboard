# %%
import mindaffectBCI.online_bci
# load the configuration file
config = mindaffectBCI.online_bci.load_config('trigger_check')

# for debugging with the fakedata source uncomment this line!
#config['acquisition']='fakedata'

# run with the loaded configuration
mindaffectBCI.online_bci.run(**config)
# Out:
# Loading config from: /Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/trigger_check.json
# Saving to /Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs
# Running command: ('java', '-jar', 'UtopiaServer.jar', '8400', '0', '/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_trigger_check.txt')
# Server:cons
# Server:open server ports
# Server: Opening Port:8400
# Server: Opening UDP Port:8400
# Server: Utopia Server listening on: UDP:8400
# llw0->/fe80:0:0:0:9c5c:90ff:fef4:2e07%llw0 ll=true
# awdl0->/fe80:0:0:0:9c5c:90ff:fef4:2e07%awdl0 ll=true
# anpi0->/fe80:0:0:0:e0f2:6eff:feed:a080%anpi0 ll=true
# anpi1->/fe80:0:0:0:e0f2:6eff:feed:a081%anpi1 ll=true
# en0->/192.168.1.101 ll=false
# Server: Opening SSDP-ipv4 Port:
# llw0->/fe80:0:0:0:9c5c:90ff:fef4:2e07%llw0 ll=truesl=false
# awdl0->/fe80:0:0:0:9c5c:90ff:fef4:2e07%awdl0 ll=truesl=false
# anpi0->/fe80:0:0:0:e0f2:6eff:feed:a080%anpi0 ll=truesl=false
# anpi1->/fe80:0:0:0:e0f2:6eff:feed:a081%anpi1 ll=truesl=false
# en0->/192.168.1.101 ll=falsesl=true
# NIC=name:en0 (en0)
# SSDP NIC: name:en0 (en0)
# Server: Utopia Server listening on: SSDP:/0.0.0.0
# Server: Opening SSDP-v6 Port:
# llw0->/fe80:0:0:0:9c5c:90ff:fef4:2e07%llw0 ll=truesl=false
# awdl0->/fe80:0:0:0:9c5c:90ff:fef4:2e07%awdl0 ll=truesl=false
# anpi0->/fe80:0:0:0:e0f2:6eff:feed:a080%anpi0 ll=truesl=false
# anpi1->/fe80:0:0:0:e0f2:6eff:feed:a081%anpi1 ll=truesl=false
# en0->/192.168.1.101 ll=falsesl=true
# NIC=name:en0 (en0)
# Server: Couldn't setup SSDP server socket
# Address family not supported by protocol family
# write description.xml
# Server:writing file: ./description.xml
# Server: Ports open, waiting for connections
# setup logging file
# Server:logging new messages to file: /Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_trigger_check_230421_1725.txt
# Server: Utopia Server Status:
# Listening on Address :
#
# /192.168.1.101:8400
# /127.0.0.1:8400
#
#  Saving to :
# /Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs/mindaffectBCI_trigger_check_230421_1725.txt
# Already initialized!
# Server:  Waiting for connections/messages
# h+
# H+
# h+
# h+
# h+
# H+
# h+
# h+
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# [2023-04-21 17:25:40.717] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:25:40.718] [board_logger] [trace] Board object created 0
# [2023-04-21 17:25:40.718] [board_logger] [info] opening port com3
# [2023-04-21 17:25:40.718] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-1:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# h+
# H+
# h+
# h+
# h+
# h+
# H+
# h+
# h+
# h+
# H+
# h+
# h+
# h+
# H+
# h+
# h+
# h+
# h+
# H+
# h+
# MacOSX
# nbAgg
# TkAgg
# WebAgg
# WX
# WXAgg
# agg
# h+
# pdf
# pgf
# ps
# svg
# template
# Initial backend: template
# Using backend: TkAgg
# Starting: mindaffectBCI.decoder.decoder
# h+
# H+
# h+
# h+
# h+
# H+
# SSDP::Query matched.  Sending response to/192.168.1.101:51151
# h+
# h+
# h+
# h+
# H+
# h+
# h+
# h+
# H+
# h+
# h+
# Acq didn't start correctly!
# h+
# H+
# h+
# h+
# h+
# h+
# H+
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# [2023-04-21 17:25:51.218] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:25:51.218] [board_logger] [trace] Board object created 0
# [2023-04-21 17:25:51.218] [board_logger] [info] opening port com3
# [2023-04-21 17:25:51.218] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-3:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# h+
# h+
# h+
# MacOSX
# nbAgg
# TkAgg
# WebAgg
# WX
# WXAgg
# agg
# pdf
# pgf
# ps
# svg
# template
# Initial backend: template
# Using backend: TkAgg
# LOGDIR=/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/decoder/../../logs/
# Trying to auto-discover the utopia-hub server
# making discovery object
# Using inteface: 192.168.1.101
# Got location: 192.168.1.101
# .
# .
# .
# .
# .
# .
# Discovery returned 1 utopia-hub servers
# Discovered utopia-hub on 192.168.1.101 ...
# Tring to connect to: 192.168.1.101:-1
# Trying to connect to: 192.168.1.101:8400
# Connected!
#
# Server: New Client Connection : /192.168.1.101:63818
#
#
# Offset Update:0.0->-1.566873419E9
# ClientInfoSubscribed /192.168.1.101:63818 to : [DEMSN]
# HH+
# h+
# h+
# h+
#
# Offset Update:-1.566873419E9->-1.566873431E9
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# HH+
# h+
# h+
# Acq didn't start correctly!
# h+
# Hh+
# H+
# h+
# h+
# [2023-04-21 17:25:57.154] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:25:57.154] [board_logger] [trace] Board object created 0
# [2023-04-21 17:25:57.154] [board_logger] [info] opening port com3
# [2023-04-21 17:25:57.154] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-4:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
#
# Offset Update:-1.566873431E9->-1.566873432E9
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# HH+
# h+
# Acq didn't start correctly!
# h+
# h+
# Hh+
# H+
# h+
# h+
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# [2023-04-21 17:26:03.118] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:26:03.118] [board_logger] [trace] Board object created 0
# [2023-04-21 17:26:03.118] [board_logger] [info] opening port com3
# [2023-04-21 17:26:03.118] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-5:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# HH+
# h+
# Acq didn't start correctly!
# h+
# h+
# Hh+
# H+
# h+
# h+
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# [2023-04-21 17:26:09.232] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:26:09.232] [board_logger] [trace] Board object created 0
# [2023-04-21 17:26:09.232] [board_logger] [info] opening port com3
# [2023-04-21 17:26:09.232] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-6:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# Hh+
# H+
# h+
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# Acq didn't start correctly!
# h+
# h+
# Hh+
# H+
# h+
# h+
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# [2023-04-21 17:26:15.276] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:26:15.276] [board_logger] [trace] Board object created 0
# [2023-04-21 17:26:15.276] [board_logger] [info] opening port com3
# [2023-04-21 17:26:15.276] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-7:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# Hh+
# H+
# h+
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# Acq didn't start correctly!
# h+
# h+
# Hh+
# H+
# h+
# h+
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# [2023-04-21 17:26:21.272] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:26:21.272] [board_logger] [trace] Board object created 0
# [2023-04-21 17:26:21.272] [board_logger] [info] opening port com3
# [2023-04-21 17:26:21.272] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-8:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# Offset Update:-1.566873432E9->-1.566873433E9
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# HH+
# h+
# Acq didn't start correctly!
# h+
# h+
# Hh+
# H+
# h+
# [2023-04-21 17:26:27.323] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:26:27.323] [board_logger] [trace] Board object created 0
# [2023-04-21 17:26:27.323] [board_logger] [info] opening port com3
# [2023-04-21 17:26:27.323] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-9:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# HH+
# h+
# Acq didn't start correctly!
# h+
# h+
# Hh+
# H+
# h+
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# [2023-04-21 17:26:33.279] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:26:33.279] [board_logger] [trace] Board object created 0
# [2023-04-21 17:26:33.279] [board_logger] [info] opening port com3
# [2023-04-21 17:26:33.279] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-10:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# h+
# Hh+
# H+
# h+
# h+
# h+
#
# Offset Update:-1.566873433E9->-1.566873434E9
# HH+
# h+
# h+
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# HH+
# Acq didn't start correctly!
# h+
# h+
# h+
# Hh+
# H+
# h+
# board_id=0 params= {'serial_port': 'com3', 'mac_address': '', 'ip_address': '', 'ip_address_aux': '', 'ip_address_anc': '', 'ip_port': 0, 'ip_port_aux': 0, 'ip_port_anc': 0, 'ip_protocol': 0, 'other_info': '', 'timeout': 0, 'serial_number': '', 'file': '', 'file_aux': '', 'file_anc': '', 'master_board': -100}
# [2023-04-21 17:26:39.331] [board_logger] [info] incoming json: {
#     "file": "",
#     "file_anc": "",
#     "file_aux": "",
#     "ip_address": "",
#     "ip_address_anc": "",
#     "ip_address_aux": "",
#     "ip_port": 0,
#     "ip_port_anc": 0,
#     "ip_port_aux": 0,
#     "ip_protocol": 0,
#     "mac_address": "",
#     "master_board": -100,
#     "other_info": "",
#     "serial_number": "",
#     "serial_port": "com3",
#     "timeout": 0
# }
# [2023-04-21 17:26:39.331] [board_logger] [trace] Board object created 0
# [2023-04-21 17:26:39.331] [board_logger] [info] opening port com3
# [2023-04-21 17:26:39.331] [board_logger] [error] Make sure you provided correct port name and have permissions to open it(run with sudo/admin). Also, close all other apps using this port.
# Process Process-11:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/Emmanuel/Documents/GitHub/pymindaffectBCI/mindaffectBCI/examples/acquisition/utopia_brainflow.py", line 122, in run
#     board.prepare_session ()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brainflow/board_shim.py", line 1141, in prepare_session
#     raise BrainFlowError('unable to prepare streaming session', res)
# brainflow.exit_codes.BrainFlowError: UNABLE_TO_OPEN_PORT_ERROR:2 unable to prepare streaming session
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# Hh+
# H+
# h+
# h+
# h+
# HH+
# h+
# h+
# h+
# HAcq didn't start correctly!
# H+
# h+
# h+
# h+
# HAcq didn't start correctly!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 9
#       3 config = mindaffectBCI.online_bci.load_config('trigger_check')
#       5 # for debugging with the fakedata source uncomment this line!
#       6 #config['acquisition']='fakedata'
#       7
#       8 # run with the loaded configuration
# ----> 9 mindaffectBCI.online_bci.run(**config)
#
# File ~/Documents/GitHub/pymindaffectBCI/mindaffectBCI/online_bci.py:294, in run(label, logdir, block, acquisition, acq_args, decoder, decoder_args, presentation, presentation_args)
#     292     print("Acq didn't start correctly!")
#     293     shutdown(hub_process,acquisition_process,decoder_process)
# --> 294     raise ValueError("acquisition didn't start correctly!")
#     295 if decoder_process is None or not decoder_process.is_alive():
#     296     shutdown(hub_process,acquisition_process,decoder_process)
#
# ValueError: acquisition didn't start correctly!
# 2023-04-21 17:26:45.591 Python[49859:558530] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/8w/l2m8r9210g3_2wybgky04r_w0000gn/T/org.python.python.savedState
# 2023-04-21 17:26:45.604 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.622 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.636 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.649 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.663 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.677 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.690 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.704 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.718 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.732 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.746 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.761 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.774 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.789 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.803 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.817 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.831 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.845 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.860 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.874 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.889 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.904 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.918 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.933 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.948 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.963 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.979 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:45.994 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.009 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.024 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.039 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.054 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.069 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.084 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.099 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.114 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.130 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.145 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.161 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.177 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.192 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.208 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.224 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.240 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.257 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.273 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.290 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.306 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.323 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.340 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.356 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.373 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.390 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.408 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.425 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.443 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.461 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.478 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.496 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.513 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.530 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.547 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.565 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.582 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.599 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.615 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.632 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.650 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.667 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.684 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.701 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.719 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.736 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.753 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.771 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.788 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.805 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.823 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.840 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.857 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.875 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.892 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.909 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.927 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.945 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.963 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.980 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:46.997 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.015 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.032 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.049 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.066 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.083 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.101 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.118 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.135 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.152 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.169 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.187 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.204 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.221 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.238 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.255 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.273 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.290 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.307 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.324 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.342 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.359 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.376 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.394 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.411 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.428 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.445 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.463 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.480 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.497 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.514 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.532 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.548 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.563 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.578 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:47.592 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# ...
# 2023-04-21 17:26:59.838 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.851 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.865 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.879 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.893 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.907 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.921 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.935 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.949 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.963 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.976 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:26:59.990 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.004 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.018 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.032 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.046 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.060 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.074 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.088 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.102 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.115 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.129 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.143 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.157 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.171 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.184 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.198 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.212 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.226 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.240 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.253 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.267 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.281 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.295 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.309 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.322 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.336 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.350 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.364 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.378 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.392 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.406 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.419 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.433 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.447 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.461 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.474 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.488 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.502 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.516 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.530 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.543 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.557 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.571 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.586 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.598 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.612 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.627 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.641 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.655 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.669 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.682 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.696 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.710 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.724 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.738 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.752 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.765 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.779 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.793 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.807 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.822 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.836 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.850 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.864 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.878 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.892 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.906 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.920 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.934 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.948 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.962 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.977 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2023-04-21 17:27:00.991 Python[49859:558530] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
